# %%
# !apt-get install -y git
# !pip install gitpython

import git
git.Repo.clone_from('https://github.com/Kirenwp/SWP_midterm_coursework.git', '/content/SWP')
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git is already the newest version (1:2.25.1-1ubuntu3.10).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gitpython in /usr/local/lib/python3.9/dist-packages (3.1.31)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.9/dist-packages (from gitpython) (4.0.10)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.9/dist-packages (from gitdb<5,>=4.0.1->gitpython) (5.0.0)
# <git.repo.base.Repo '/content/SWP/.git'>

# %%
import tensorflow as tf; tf.compat.v1.disable_eager_execution()
from keras import backend as K
from keras.layers import Input, Dense, Conv2D, Conv2DTranspose, Flatten, Lambda, Reshape
from keras.models import Model
from keras.losses import binary_crossentropy

# %%
import os
from tqdm import tqdm
import cv2
from google.colab.patches import cv2_imshow
from tensorflow.keras.utils import img_to_array
from keras import regularizers
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import keras
from keras.optimizers import rmsprop_v2
import keras
from keras.layers import Conv2DTranspose, ConvLSTM2D, BatchNormalization, TimeDistributed, Conv2D
from keras.models import Sequential, load_model
from keras.layers import LayerNormalization
from skimage import color
from skimage.transform import resize, rotate

# %%
SIZE = 256

#！！ use cropped data
# Data set
# For training /content/CUHK Dataset/CUHK_testing_cropped_sketche
image_path = '/content/SWP/CUHK Dataset/CUHK_training_cropped_photos/'
img_array = []

sketch_path = '/content/SWP/CUHK Dataset/CUHK_training_cropped_sketches/'
sketch_array = []

# For testing
test_image_path = '/content/SWP/CUHK Dataset/CUHK_testing_cropped_photos/'
test_img_array = []

test_sketch_path = '/content/SWP/CUHK Dataset/CUHK_testing_cropped_sketches/'
test_sketch_array = []



# Image and their corresponding file names in a sorted manner based on their names
image_file = sorted(os.listdir(image_path))
sketch_file = sorted(os.listdir(sketch_path))
test_image_file = sorted(os.listdir(test_image_path))
test_sketch_file = sorted(os.listdir(test_sketch_path))
# to get the files in proper order

# %%
def image_preprocessing(file_name, img_path, size):
  storage_array = []
  for img_file in tqdm(file_name):
    x = img_path + img_file
    img = (cv2.resize(cv2.imread(x,cv2.IMREAD_COLOR).astype('float32'),(SIZE,SIZE)))/255.0
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    storage_array.append(img)
    
  # Returning storage array where we have stored all our pre-processed images
  return np.array(storage_array)

# %%
img_array = image_preprocessing(image_file, image_path, SIZE)
sketch_array = image_preprocessing(sketch_file, sketch_path, SIZE)
test_img_array = image_preprocessing(test_image_file, test_image_path, SIZE)
test_sketch_array = image_preprocessing(test_sketch_file, test_sketch_path, SIZE)
# Out:
# 100%|██████████| 88/88 [01:13<00:00,  1.19it/s]
# 100%|██████████| 88/88 [01:07<00:00,  1.30it/s]
# 100%|██████████| 100/100 [01:14<00:00,  1.35it/s]
# 100%|██████████| 100/100 [01:13<00:00,  1.35it/s]

# %%
# Print the number of colored and sketch images present
print("Total number of Training Colored images:",len(img_array))
print("Total number of Training sketch images:",len(sketch_array))
print("Total number of Testing Colored images:",len(test_img_array))
print("Total number of Testing sketch images:",len(test_sketch_array))
# Out:
# Total number of Training Colored images: 88
# Total number of Training sketch images: 88
# Total number of Testing Colored images: 100
# Total number of Testing sketch images: 100

# %%
# Converting the image arrays into numpy for easy processing 
img_array_n = np.array(img_array)
sketch_array_n = np.array(sketch_array)

test_img_array_n = np.array(test_img_array)
test_sketch_array_n = np.array(test_sketch_array)

# Printing the shapes of the image 
print("The shape of the train colored image array is:", img_array_n.shape)
print("The shape of the train sketched image array is:", sketch_array_n.shape)

print("The shape of the test colored image array is:", test_img_array_n.shape)
print("The shape of the test sketched image array is:", test_sketch_array_n.shape)
# Out:
# The shape of the train colored image array is: (88, 256, 256, 3)
# The shape of the train sketched image array is: (88, 256, 256, 3)
# The shape of the test colored image array is: (100, 256, 256, 3)
# The shape of the test sketched image array is: (100, 256, 256, 3)

# %%
# Plotting the training images to see
some_photos = np.concatenate([i for i in img_array_n[:5]],axis=1)
some_sketches = np.concatenate([i for i in sketch_array_n[:5]],axis=1)
plt.figure(figsize=(20,10))
plt.imshow(np.concatenate([some_photos,some_sketches]))
plt.axis("OFF")
plt.show()

# %%
# Plotting the testing images to see
some_photos = np.concatenate([i for i in test_img_array_n[:10]],axis=1)
some_sketches = np.concatenate([i for i in test_sketch_array_n[:10]],axis=1)
plt.figure(figsize=(20,10))
plt.imshow(np.concatenate([some_photos,some_sketches]))
plt.axis("OFF")
plt.show()

# %%
(X_train, y_train), (X_test, y_test) = (img_array_n, sketch_array_n), (test_img_array_n, test_sketch_array_n)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((88, 256, 256, 3), (88, 256, 256, 3), (100, 256, 256, 3), (100, 256, 256, 3))

# %% [markdown]
# ## Construction of Encoder

# %%
img_height   = X_train.shape[1]    # 256
img_width    = X_train.shape[2]    # 256
num_channels = X_train.shape[3]    # 3

input_shape =  (img_height, img_width, num_channels)   # (256, 256, 3) 
latent_dim = 16   # Dimension of the latent space

# %%
encoder_input = Input(shape=input_shape)

encoder_conv = Conv2D(filters=8, kernel_size=3, strides=2, padding='same', activation='relu')(encoder_input)

encoder_conv = Conv2D(filters=16, kernel_size=3, strides=2, padding='same', activation='relu')(encoder_conv)
encoder_conv = keras.layers.LeakyReLU()(encoder_conv)

encoder_conv = Conv2D(filters=32, kernel_size=3, strides=2, padding='same', activation='relu')(encoder_conv)
encoder_conv = keras.layers.BatchNormalization()(encoder_conv)
encoder_conv = keras.layers.LeakyReLU()(encoder_conv)

encoder_conv = Conv2D(filters=64, kernel_size=3, strides=2, padding='same', activation='relu')(encoder_conv)
encoder_conv = keras.layers.LeakyReLU()(encoder_conv)

encoder_conv = Conv2D(filters=128, kernel_size=3, strides=2, padding='same', activation='relu')(encoder_conv)
encoder_conv = keras.layers.BatchNormalization()(encoder_conv)
encoder_conv = keras.layers.LeakyReLU()(encoder_conv)

encoder_conv = Conv2D(filters=256, kernel_size=3, strides=2, padding='same', activation='relu')(encoder_conv)
encoder_conv = keras.layers.BatchNormalization()(encoder_conv)
encoder_conv = keras.layers.LeakyReLU()(encoder_conv)

encoder_conv = Conv2D(filters=512, kernel_size=3, strides=2, padding='same', activation='relu')(encoder_conv)
encoder_conv = keras.layers.BatchNormalization()(encoder_conv)
encoder_conv = keras.layers.LeakyReLU()(encoder_conv)

encoder = Flatten()(encoder_conv)

mu = Dense(latent_dim)(encoder)
sigma = Dense(latent_dim)(encoder)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/keras/layers/normalization/batch_normalization.py:561: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ## To determine the values in the latent space layer

# %%
def compute_latent(x):
    mu, sigma = x
    batch = K.shape(mu)[0]
    dim = K.int_shape(mu)[1]
    eps = K.random_normal(shape=(batch,dim))
    return mu + K.exp(sigma/2)*eps

# %% [markdown]
# ## Reparameterization

# %%
latent_space = Lambda(compute_latent, output_shape=(latent_dim,))([mu, sigma])

# %%
conv_shape = K.int_shape(encoder_conv)

# %%
conv_shape
# Out:
# (None, 2, 2, 512)

# %% [markdown]
# ## Construction of Decoder

# %%
decoder_input = Input(shape=(latent_dim,))

decoder = Dense(conv_shape[1]*conv_shape[2]*conv_shape[3], activation='relu')(decoder_input)

decoder = Reshape((conv_shape[1], conv_shape[2], conv_shape[3]))(decoder)

decoder_conv = Conv2DTranspose(filters=512, kernel_size=3, strides=2, padding='same', activation='relu')(decoder)
decoder_conv = keras.layers.Dropout(0.1)(decoder_conv)
decoder_conv = keras.layers.LeakyReLU()(decoder_conv)

decoder_conv = Conv2DTranspose(filters=256, kernel_size=3, strides=2, padding='same', activation='relu')(decoder_conv)
decoder_conv = keras.layers.LeakyReLU()(decoder_conv)

decoder_conv = Conv2DTranspose(filters=128, kernel_size=3, strides=2, padding='same', activation='relu')(decoder_conv)
decoder_conv = keras.layers.Dropout(0.1)(decoder_conv)
decoder_conv = keras.layers.LeakyReLU()(decoder_conv)

decoder_conv = Conv2DTranspose(filters=64, kernel_size=3, strides=2, padding='same', activation='relu')(decoder_conv)
decoder_conv = keras.layers.LeakyReLU()(decoder_conv)

decoder_conv = Conv2DTranspose(filters=32, kernel_size=3, strides=2, padding='same', activation='relu')(decoder_conv)
decoder_conv = keras.layers.LeakyReLU()(decoder_conv)

decoder_conv = Conv2DTranspose(filters=16, kernel_size=3, strides=2, padding='same', activation='relu')(decoder_conv)
decoder_conv = keras.layers.LeakyReLU()(decoder_conv)

decoder_conv = Conv2DTranspose(filters=8, kernel_size=3, strides=2, padding='same', activation='relu')(decoder_conv)

decoder_conv =  Conv2DTranspose(filters=num_channels, kernel_size=3, padding='same', activation='sigmoid')(decoder_conv)

# %% [markdown]
# ## Connecting the encoder and decoder

# %%
encoder = Model(encoder_input, latent_space)
decoder = Model(decoder_input, decoder_conv)

# %% [markdown]
# ## The output of vae model is the output of decoder in which its input is taken from the output of encoder

# %%
vae = Model(encoder_input, decoder(encoder(encoder_input)))

# %% [markdown]
# ## Summary of autoencoder

# %%
vae.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  model (Functional)          (None, 16)                1642992
#
#  model_1 (Functional)        (None, 256, 256, 3)       3967827
#
# =================================================================
# Total params: 5,610,819
# Trainable params: 5,608,963
# Non-trainable params: 1,856
# _________________________________________________________________

# %% [markdown]
# ## Summary of encoder

# %%
encoder.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 8)  224         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 16)   1168        ['conv2d[0][0]']
#
#  leaky_re_lu (LeakyReLU)        (None, 64, 64, 16)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 32)   4640        ['leaky_re_lu[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 32)  128         ['conv2d_2[0][0]']
#  alization)
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 32, 32, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 16, 16, 64)   18496       ['leaky_re_lu_1[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 16, 16, 64)   0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 8, 8, 128)    73856       ['leaky_re_lu_2[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 8, 8, 128)   512         ['conv2d_4[0][0]']
#  rmalization)
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 8, 8, 128)    0           ['batch_normalization_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 4, 4, 256)    295168      ['leaky_re_lu_3[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 4, 4, 256)   1024        ['conv2d_5[0][0]']
#  rmalization)
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 4, 4, 256)    0           ['batch_normalization_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 2, 2, 512)    1180160     ['leaky_re_lu_4[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 2, 2, 512)   2048        ['conv2d_6[0][0]']
#  rmalization)
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 2, 2, 512)    0           ['batch_normalization_3[0][0]']
#
#  flatten (Flatten)              (None, 2048)         0           ['leaky_re_lu_5[0][0]']
#
#  dense (Dense)                  (None, 16)           32784       ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 16)           32784       ['flatten[0][0]']
#
#  lambda (Lambda)                (None, 16)           0           ['dense[0][0]',
#                                                                   'dense_1[0][0]']
#
# ==================================================================================================
# Total params: 1,642,992
# Trainable params: 1,641,136
# Non-trainable params: 1,856
# __________________________________________________________________________________________________

# %% [markdown]
# ## Summary of decoder

# %%
decoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 16)]              0
#
#  dense_2 (Dense)             (None, 2048)              34816
#
#  reshape (Reshape)           (None, 2, 2, 512)         0
#
#  conv2d_transpose (Conv2DTra  (None, 4, 4, 512)        2359808
#  nspose)
#
#  dropout (Dropout)           (None, 4, 4, 512)         0
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 4, 4, 512)         0
#
#  conv2d_transpose_1 (Conv2DT  (None, 8, 8, 256)        1179904
#  ranspose)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 8, 8, 256)         0
#
#  conv2d_transpose_2 (Conv2DT  (None, 16, 16, 128)      295040
#  ranspose)
#
#  dropout_1 (Dropout)         (None, 16, 16, 128)       0
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 16, 16, 128)       0
#
#  conv2d_transpose_3 (Conv2DT  (None, 32, 32, 64)       73792
#  ranspose)
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 32, 32, 64)        0
#
#  conv2d_transpose_4 (Conv2DT  (None, 64, 64, 32)       18464
#  ranspose)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 64, 64, 32)        0
#
#  conv2d_transpose_5 (Conv2DT  (None, 128, 128, 16)     4624
#  ranspose)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 128, 128, 16)      0
#
#  conv2d_transpose_6 (Conv2DT  (None, 256, 256, 8)      1160
#  ranspose)
#
#  conv2d_transpose_7 (Conv2DT  (None, 256, 256, 3)      219
#  ranspose)
#
# =================================================================
# Total params: 3,967,827
# Trainable params: 3,967,827
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Defining loss function

# %%
def kl_reconstruction_loss(true, pred):    # Reconstruction loss
    reconstruction_loss = binary_crossentropy(K.flatten(true), K.flatten(pred)) * img_width * img_height    
    
    # KL divergence loss
    kl_loss = 1 + sigma - K.square(mu) - K.exp(sigma)
    kl_loss = K.sum(kl_loss, axis=-1)
    kl_loss *= -0.5    
    
    # Total loss = 50% rec + 50% KL divergence loss
    return K.mean(reconstruction_loss + kl_loss)

# %% [markdown]
# ## Compiling the model

# %%
vae.compile(optimizer='adam', loss=kl_reconstruction_loss)

# %% [markdown]
# ## Training the model

# %%
history = vae.fit(y=X_train, x=y_train, epochs=100, batch_size=16, validation_data=(y_test,X_test))
# Out:
# Train on 88 samples, validate on 100 samples
# Epoch 1/100
# 88/88 [==============================] - ETA: 0s - loss: 45418.6069
# /usr/local/lib/python3.9/dist-packages/keras/engine/training_v1.py:2333: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 88/88 [==============================] - 14s 164ms/sample - loss: 45418.6069 - val_loss: 45359.9694
# Epoch 2/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 45306.5501 - val_loss: 45201.5850
# Epoch 3/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 44863.2408 - val_loss: 44828.7581
# Epoch 4/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 43796.4812 - val_loss: 44515.0844
# Epoch 5/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 42689.2436 - val_loss: 44154.2734
# Epoch 6/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 41878.5121 - val_loss: 43770.1097
# Epoch 7/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 41239.4588 - val_loss: 43547.8056
# Epoch 8/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 40993.4723 - val_loss: 43250.8159
# Epoch 9/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 40891.6591 - val_loss: 43090.1450
# Epoch 10/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 40730.9105 - val_loss: 43262.7441
# Epoch 11/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 40519.2138 - val_loss: 43254.6581
# Epoch 12/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 40389.5941 - val_loss: 43215.8153
# Epoch 13/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 40185.6499 - val_loss: 42771.2586
# Epoch 14/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 39768.4553 - val_loss: 42323.7598
# Epoch 15/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 39164.2088 - val_loss: 41998.0706
# Epoch 16/100
# 88/88 [==============================] - 1s 7ms/sample - loss: 38444.2809 - val_loss: 41185.4745
# Epoch 17/100
# 88/88 [==============================] - 1s 8ms/sample - loss: 38070.7248 - val_loss: 40674.0777
# Epoch 18/100
# 88/88 [==============================] - 1s 7ms/sample - loss: 37834.8246 - val_loss: 40484.0084
# Epoch 19/100
# 88/88 [==============================] - 1s 8ms/sample - loss: 37739.4254 - val_loss: 40526.7628
# Epoch 20/100
# 88/88 [==============================] - 1s 8ms/sample - loss: 37658.1804 - val_loss: 40205.9998
# Epoch 21/100
# 88/88 [==============================] - 1s 7ms/sample - loss: 37553.5803 - val_loss: 40005.4552
# Epoch 22/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 37420.9027 - val_loss: 40275.1644
# Epoch 23/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 37206.0732 - val_loss: 39797.9897
# Epoch 24/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 37115.4379 - val_loss: 39781.4728
# Epoch 25/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 36942.1499 - val_loss: 39782.2347
# Epoch 26/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 36918.5362 - val_loss: 39719.0131
# Epoch 27/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 36654.9759 - val_loss: 39437.8133
# Epoch 28/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 36431.0153 - val_loss: 39388.3839
# Epoch 29/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 36114.6726 - val_loss: 38913.5284
# Epoch 30/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 35653.2734 - val_loss: 37918.5837
# Epoch 31/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 35245.5923 - val_loss: 37774.0633
# Epoch 32/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 35270.9318 - val_loss: 37905.5300
# Epoch 33/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 34795.2273 - val_loss: 37919.3962
# Epoch 34/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 34601.8452 - val_loss: 37559.9644
# Epoch 35/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 34530.8448 - val_loss: 37521.0512
# Epoch 36/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 34429.8242 - val_loss: 37655.6462
# Epoch 37/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 34395.6307 - val_loss: 37233.0566
# Epoch 38/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 34341.8629 - val_loss: 37178.5225
# Epoch 39/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 34257.3523 - val_loss: 37081.4091
# Epoch 40/100
# 88/88 [==============================] - 1s 7ms/sample - loss: 34323.3920 - val_loss: 37066.2272
# Epoch 41/100
# 88/88 [==============================] - 1s 8ms/sample - loss: 34258.6772 - val_loss: 38849.7666
# Epoch 42/100
# 88/88 [==============================] - 1s 8ms/sample - loss: 34183.4141 - val_loss: 40667.5953
# Epoch 43/100
# 88/88 [==============================] - 1s 8ms/sample - loss: 34184.1903 - val_loss: 43927.2412
# Epoch 44/100
# 88/88 [==============================] - 1s 8ms/sample - loss: 34181.6151 - val_loss: 43281.2539
# Epoch 45/100
# 88/88 [==============================] - 1s 8ms/sample - loss: 34233.7976 - val_loss: 43881.1802
# Epoch 46/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 33935.4943 - val_loss: 39695.5347
# Epoch 47/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 33834.0291 - val_loss: 37752.8139
# Epoch 48/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 33798.1584 - val_loss: 37268.1241
# Epoch 49/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 33703.2063 - val_loss: 39757.2417
# Epoch 50/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 33687.8825 - val_loss: 37542.7908
# Epoch 51/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 33655.3438 - val_loss: 37414.7300
# Epoch 52/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 33506.2571 - val_loss: 37495.0648
# Epoch 53/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 33507.2195 - val_loss: 37752.7180
# Epoch 54/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 33444.8530 - val_loss: 37955.2613
# Epoch 55/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 33542.6953 - val_loss: 37429.3722
# Epoch 56/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 33418.6349 - val_loss: 39254.9775
# Epoch 57/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 33364.0043 - val_loss: 38599.0338
# Epoch 58/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 33244.7290 - val_loss: 38052.2491
# Epoch 59/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 33339.5653 - val_loss: 38317.0894
# Epoch 60/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 33221.0604 - val_loss: 37481.1877
# Epoch 61/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 33221.2287 - val_loss: 37301.1666
# Epoch 62/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 33214.4986 - val_loss: 37351.9166
# Epoch 63/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 33188.4485 - val_loss: 37192.3102
# Epoch 64/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 33205.5661 - val_loss: 37215.5694
# Epoch 65/100
# 88/88 [==============================] - 1s 7ms/sample - loss: 33182.3629 - val_loss: 37504.0141
# Epoch 66/100
# 88/88 [==============================] - 1s 8ms/sample - loss: 33218.9197 - val_loss: 37597.5519
# Epoch 67/100
# 88/88 [==============================] - 1s 8ms/sample - loss: 33165.1942 - val_loss: 37794.3336
# Epoch 68/100
# 88/88 [==============================] - 1s 8ms/sample - loss: 33081.1286 - val_loss: 38103.7680
# Epoch 69/100
# 88/88 [==============================] - 1s 7ms/sample - loss: 33055.6200 - val_loss: 37063.2172
# Epoch 70/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 33010.0447 - val_loss: 37115.0486
# Epoch 71/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 32963.6889 - val_loss: 37158.2270
# Epoch 72/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 32943.5518 - val_loss: 37074.3250
# Epoch 73/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 32992.3475 - val_loss: 37300.1748
# Epoch 74/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 32996.4645 - val_loss: 37173.5544
# Epoch 75/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 32986.4297 - val_loss: 37499.4200
# Epoch 76/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 33023.6850 - val_loss: 37221.3795
# Epoch 77/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 33051.2770 - val_loss: 36981.2847
# Epoch 78/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 33043.5579 - val_loss: 37731.5009
# Epoch 79/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 33063.9180 - val_loss: 37918.4367
# Epoch 80/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 33043.6848 - val_loss: 37329.5056
# Epoch 81/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 32967.6009 - val_loss: 36975.1609
# Epoch 82/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 32917.3739 - val_loss: 37264.9509
# Epoch 83/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 32856.9336 - val_loss: 37160.0666
# Epoch 84/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 32841.4489 - val_loss: 37624.3839
# Epoch 85/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 32800.2170 - val_loss: 37472.9284
# Epoch 86/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 32784.1992 - val_loss: 37411.6306
# Epoch 87/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 32739.0710 - val_loss: 37048.2588
# Epoch 88/100
# 88/88 [==============================] - 1s 7ms/sample - loss: 32709.5117 - val_loss: 36865.0231
# Epoch 89/100
# 88/88 [==============================] - 1s 8ms/sample - loss: 32723.0483 - val_loss: 36899.3209
# Epoch 90/100
# 88/88 [==============================] - 1s 8ms/sample - loss: 32833.5398 - val_loss: 36929.9613
# Epoch 91/100
# 88/88 [==============================] - 1s 8ms/sample - loss: 32739.9904 - val_loss: 37258.9163
# Epoch 92/100
# 88/88 [==============================] - 1s 8ms/sample - loss: 32732.5259 - val_loss: 37152.7728
# Epoch 93/100
# 88/88 [==============================] - 1s 8ms/sample - loss: 32742.0526 - val_loss: 37344.1053
# Epoch 94/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 32823.3594 - val_loss: 37825.4205
# Epoch 95/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 32768.5732 - val_loss: 37344.7425
# Epoch 96/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 32684.1349 - val_loss: 36989.3125
# Epoch 97/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 32677.8224 - val_loss: 37261.7328
# Epoch 98/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 32668.3837 - val_loss: 37235.7116
# Epoch 99/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 32653.4769 - val_loss: 37268.7000
# Epoch 100/100
# 88/88 [==============================] - 1s 6ms/sample - loss: 32619.5607 - val_loss: 37194.5683

# %% [markdown]
# ## Loss value of both train and test data

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Training loss', 'Validation loss'])

# %% [markdown]
# ## Displaying latent space

# %%
encoded = encoder.predict(y_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/engine/training_v1.py:2357: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %% [markdown]
# ## Decoding data points in latent space

# %%
def display_image_sequence(x_start,y_start,x_end,y_end,no_of_imgs):
    x_axis = np.linspace(x_start,x_end,no_of_imgs)
    y_axis = np.linspace(y_start,y_end,no_of_imgs)
    
    x_axis = x_axis[:, np.newaxis]
    y_axis = y_axis[:, np.newaxis]
    
    new_points = np.hstack((x_axis, y_axis))

    print(new_points.shape)

    new_images = decoder.predict(new_points)
    print(new_images.shape)
    
    new_images = new_images.reshape(new_images.shape[0], new_images.shape[1], new_images.shape[2], new_images.shape[3])
    
    # Display some images
    fig, axes = plt.subplots(ncols=no_of_imgs, sharex=False, sharey=True, figsize=(20, 7))
    counter = 0
    for i in range(no_of_imgs):
        axes[counter].imshow(new_images[i], cmap='gray')
        axes[counter].get_xaxis().set_visible(False)
        axes[counter].get_yaxis().set_visible(False)
        counter += 1
    plt.show()

# %%
for i in range(60,70):
  img_no = i
  fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(5, 3))
  axes[0].imshow(y_test[img_no])
  axes[1].imshow(X_test[img_no])
  axes[2].imshow(vae.predict(y_test)[img_no])
  fig.tight_layout()

# %%
some_photos = []
sketch_photos = []
for i in range(9, 90, 7):
  some_photos.append(X_test[i])
  sketch_photos.append(vae.predict(y_test)[i])


X = np.concatenate(some_photos, axis=1)
Y = np.concatenate(sketch_photos, axis=1)

plt.figure(figsize=(20,10))
plt.imshow(np.concatenate([X,Y]))
plt.axis("OFF")

plt.show()
